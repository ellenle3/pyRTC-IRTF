# %%
import numpy as np
import matplotlib.pyplot as plt


import pyRTC.utils as utils
from pyRTC import *
from astropy.io import fits

from cacofoni.make_cacofoni import make_cacofoni
# Out:
# Spinnaker python SDK installation not found
# Spinnaker python SDK installation not found
# ximea python SDK installation not found
# PI python SDK installation not found

# %%
conf = utils.read_yaml_file("config_felixsim.yaml")
telemetry = ImakaTelemetry(conf=conf["telemetry"])

# %% [markdown]
# ## Save aocbs

# %%
telemetry.dataDir = "data/20251004/"
telemetry.setNumIter(1000)

# %%
num_aocbs = 2
idx_start = 20  # starting index of aocb file

fns_aocb = []
for i in range(num_aocbs):
    fnout = telemetry.save(idx_start, saveWFSImages=True)
    idx_start += 1
    fns_aocb.append(fnout)
# Out:
# Opening Existing Shared Memory Object wfs_meta
# Closing wfs_meta
# Opening Existing Shared Memory Object wfs
# Opening Existing Shared Memory Object wfs_meta
# Opening Existing Shared Memory Object wfsRaw_meta
# Closing wfsRaw_meta
# Opening Existing Shared Memory Object wfsRaw
# Opening Existing Shared Memory Object wfsRaw_meta
# Opening Existing Shared Memory Object signal_meta
# Closing signal_meta
# Opening Existing Shared Memory Object signal
# Opening Existing Shared Memory Object signal_meta
# Opening Existing Shared Memory Object wfc2D_meta
# Closing wfc2D_meta
# Opening Existing Shared Memory Object wfc2D
# Opening Existing Shared Memory Object wfc2D_meta
# Opening Existing Shared Memory Object m2c_meta
# Closing m2c_meta
# Opening Existing Shared Memory Object m2c
# Opening Existing Shared Memory Object m2c_meta
# Opening Existing Shared Memory Object loop_meta
# Closing loop_meta
# Opening Existing Shared Memory Object loop
# Opening Existing Shared Memory Object loop_meta
# Opening Existing Shared Memory Object cmat_meta
# Closing cmat_meta
# Opening Existing Shared Memory Object cmat
# Opening Existing Shared Memory Object cmat_meta
# Opening Existing Shared Memory Object refSlopes_meta
# Closing refSlopes_meta
# Opening Existing Shared Memory Object refSlopes
# Opening Existing Shared Memory Object refSlopes_meta
# Closing wfs
# Closing wfsRaw
# Closing signal
# Closing wfc2D
# Closing m2c
# Closing loop
# Closing cmat
# Closing refSlopes
# Opening Existing Shared Memory Object wfs_meta
# Closing wfs_meta
# Opening Existing Shared Memory Object wfs
# Opening Existing Shared Memory Object wfs_meta
# Opening Existing Shared Memory Object wfsRaw_meta
# Closing wfsRaw_meta
# Opening Existing Shared Memory Object wfsRaw
# Opening Existing Shared Memory Object wfsRaw_meta
# Opening Existing Shared Memory Object signal_meta
# Closing signal_meta
# Opening Existing Shared Memory Object signal
# Opening Existing Shared Memory Object signal_meta
# Opening Existing Shared Memory Object wfc2D_meta
# Closing wfc2D_meta
# Opening Existing Shared Memory Object wfc2D
# Opening Existing Shared Memory Object wfc2D_meta
# Opening Existing Shared Memory Object m2c_meta
# Closing m2c_meta
# Opening Existing Shared Memory Object m2c
# Opening Existing Shared Memory Object m2c_meta
# Opening Existing Shared Memory Object loop_meta
# Closing loop_meta
# Opening Existing Shared Memory Object loop
# Opening Existing Shared Memory Object loop_meta
# Opening Existing Shared Memory Object cmat_meta
# Closing cmat_meta
# Opening Existing Shared Memory Object cmat
# Opening Existing Shared Memory Object cmat_meta
# Opening Existing Shared Memory Object refSlopes_meta
# Closing refSlopes_meta
# Opening Existing Shared Memory Object refSlopes
# Opening Existing Shared Memory Object refSlopes_meta
# Closing wfs
# Closing wfsRaw
# Closing signal
# Closing wfc2D
# Closing m2c
# Closing loop
# Closing cmat
# Closing refSlopes

# %% [markdown]
# ## CACOFONI imat
# Verify the following:
# - leakyIntegrator is being used and loop is running
# - pbGain > 0; you should be able to see the modulation
# - loop.setNumDroppedModes(0)

# %%
telemetry.setNumIter(60)

# %%
# Record telemetry for CACOFONI once you're set up properly
num_aocbs = 2
idx_start = 10  # starting index of aocb file

fns_aocb = []
for i in range(num_aocbs):
    fnout = telemetry.save(idx_start, saveWFSImages=True)
    idx_start += 1
    fns_aocb.append(fnout)
# Out:
# Opening Existing Shared Memory Object wfs_meta
# Closing wfs_meta
# Opening Existing Shared Memory Object wfs
# Opening Existing Shared Memory Object wfs_meta
# Opening Existing Shared Memory Object wfsRaw_meta
# Closing wfsRaw_meta
# Opening Existing Shared Memory Object wfsRaw
# Opening Existing Shared Memory Object wfsRaw_meta
# Opening Existing Shared Memory Object signal_meta
# Closing signal_meta
# Opening Existing Shared Memory Object signal
# Opening Existing Shared Memory Object signal_meta
# Opening Existing Shared Memory Object wfc2D_meta
# Closing wfc2D_meta
# Opening Existing Shared Memory Object wfc2D
# Opening Existing Shared Memory Object wfc2D_meta
# Opening Existing Shared Memory Object m2c_meta
# Closing m2c_meta
# Opening Existing Shared Memory Object m2c
# Opening Existing Shared Memory Object m2c_meta
# Opening Existing Shared Memory Object loop_meta
# Closing loop_meta
# Opening Existing Shared Memory Object loop
# Opening Existing Shared Memory Object loop_meta
# Opening Existing Shared Memory Object cmat_meta
# Closing cmat_meta
# Opening Existing Shared Memory Object cmat
# Opening Existing Shared Memory Object cmat_meta
# Opening Existing Shared Memory Object refSlopes_meta
# Closing refSlopes_meta
# Opening Existing Shared Memory Object refSlopes
# Opening Existing Shared Memory Object refSlopes_meta
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 7
#       5 fns_aocb = []
#       6 for i in range(num_aocbs):
# ----> 7     fnout = telemetry.save(idx_start, saveWFSImages=True)
#       8     idx_start += 1
#       9     fns_aocb.append(fnout)
#
# File ~/src/pyrtc/pyRTC-IRTF/pyRTC/ImakaTelemetry.py:76, in ImakaTelemetry.save(self, idx, saveWFSImages)
#      73 fname = os.path.join(self.dataDir, f"{self.prefix}{idx:04d}.fits")
#      74 fname = os.path.abspath(fname)
# ---> 76 self.recordData(saveWFSImages)
#      78 # ext0: loop state (niter, np). np = 5 currently
#      79 hdu0 = fits.PrimaryHDU(data=np.array(self.loopParams, dtype='>i8'))
#
# File ~/src/pyrtc/pyRTC-IRTF/pyRTC/ImakaTelemetry.py:165, in ImakaTelemetry.recordData(self, saveWFSImages)
#     160 cumulativeCommands = np.zeros((2, self.n_channels), dtype='f4')
#     162 for i in range(self.numIter):
#     163
#     164     # block here because it will update with each loop iteration
# --> 165     self.loopParams.append( loopShm.read() )
#     167     # do not block for all of the below, e.g., refSlopes may not be updated
#     168     # between loop iterations
#     169     slopes = signalShm.read_noblock()
#
# File ~/src/pyrtc/pyRTC-IRTF/pyRTC/Pipeline.py:330, in ImageSHM.read(self, SAFE, GPU, RELEASE_GIL)
#     329 def read(self, SAFE=True, GPU = False, RELEASE_GIL = True):
# --> 330     self.hold(RELEASE_GIL = RELEASE_GIL)
#     331     return self.read_noblock(SAFE=SAFE, GPU=GPU)
#
# File ~/src/pyrtc/pyRTC-IRTF/pyRTC/Pipeline.py:317, in ImageSHM.hold(self, timeout, RELEASE_GIL)
#     315 while not self.checkNew():
#     316     if RELEASE_GIL:
# --> 317         time.sleep(1e-5)
#     318     else:
#     319         precise_delay(5)
#
# KeyboardInterrupt:

# %%
fns_aocb = ['/Users/ellenlee/Documents/pyRTC-IRTF/IRTF/data/20250930/aocb0003.fits']

# %%
fns_aocb = ['/Users/ellenlee/Documents/pyRTC-IRTF/IRTF/data/aocb0003.fits']

# %%
imats = []
z2a_file = "calib/z2a.empirical_norm.20250408b.7modes.fits"
#z2a_file = "calib/z2a.20240409b.7modes.fits"
for fn in fns_aocb:
    freq, psdmes, psdmod, filter_mask, imat, laplacian = make_cacofoni(
        telemetry_filepath=fn,
        modal_filepath=z2a_file,
        modal=True,
        closed=None,
        choose_n_steps=None,
        start_index=None,
        silent=False,
        debug=True,
        config=None,
        keep_as_modal=True
    )
    imats.append(imat)
imat = np.average(imats, axis=0)

plt.figure()
plt.imshow(imat)
plt.show()
# Out:
# Setting up make_cacofoni...
#
# [Config] Assuming 7 actuators from config for loading telemetry data.
# [Config] Assuming 2 'x' subapertures from config for loading telemetry data.
# [Config] Assuming 2 'y' subapertures from config for loading telemetry data.
#
# [Config] Assuming 3.0 Hz for minimum frequency.
# [Config] Assuming 5.0 Hz for maximum frequency.
#
# Using user-provided file: /home/felix/src/pyrtc/pyRTC-IRTF/IRTF/data/20251002/aocb0004.fits
#
# Loading imaka telemetry file...
#
# Loading Extension 0: Loop state
# ------------------------------------------------
# Shape of Extension             = (15535, 5)
# Loading                        = 'clocktime' in 'loop'
# Key Shape                      = 'clocktime': (15535,)
# ------------------------------------------------
#
# Loading Extension 3: Centroids
# ------------------------------------------------
# Shape of Extension             = (15535, 1, 8)
# Loading                        = 'xcentroids' in 'wfs'
# Key Shape                      = (15535, 1, 4)
# Loading                        = 'ycentroids' in 'wfs'
# Key Shape                      = (15535, 1, 4)
# ------------------------------------------------
#
# Loading Extension 4: DM Voltages
# ------------------------------------------------
# Shape of Extension             = (15535, 2, 64)
# Loading                        = 'deltav' in 'dm'
# Key Shape                      = (15535, 7)
# Loading                        = 'voltage' in 'dm'
# Key Shape                      = (15535, 7)
# ------------------------------------------------
#
# 4
# Assumptions from telemetry file:
# ------------------------------------------------
# Number of time steps           = 15535
# Average time interval (s)      = 0.0105
# Approximate runtime (s)        = 163
#
# Number of wavefront sensors    = 1
# Number of actuators            = 7
#
# Number of x centroids          = 4
# Number of y centroids          = 4
# Total number of centroids      = 8
#
# Sampling frequency (Hz)        = 95.00
# Nyquist frequency (Hz)         = 47.50
# ------------------------------------------------
#
# Loading modal file and computing modal commands...
#
# Using user-provided file: /home/felix/src/pyrtc/pyRTC-IRTF/IRTF/calib/z2a.empirical_norm.20250408b.7modes.fits
#
# Preparing for interaction matrix...
#
# Actuator 0: No strong peak found.
# Actuator 1: No strong peak found.
# Actuator 2: No strong peak found.
# Actuator 3: No strong peak found.
# Actuator 4: No strong peak found.
# Actuator 5: No strong peak found.
# Actuator 6: No strong peak found.
# Actuator 7: No strong peak found.
# Actuator 8: No strong peak found.
# Actuator 9: No strong peak found.
# Actuator 10: No strong peak found.
# Actuator 11: No strong peak found.
# Actuator 12: No strong peak found.
# Actuator 13: No strong peak found.
# Actuator 14: No strong peak found.
# Actuator 15: No strong peak found.
# Actuator 16: No strong peak found.
# Actuator 17: No strong peak found.
# Actuator 18: No strong peak found.
# Actuator 19: No strong peak found.
# Actuator 20: No strong peak found.
# Actuator 21: No strong peak found.
# Actuator 22: No strong peak found.
# Actuator 23: No strong peak found.
# Actuator 24: No strong peak found.
# Actuator 25: No strong peak found.
# Actuator 26: No strong peak found.
# Actuator 27: No strong peak found.
# Actuator 28: No strong peak found.
# Actuator 29: No strong peak found.
# Actuator 30: No strong peak found.
# Actuator 31: No strong peak found.
# Actuator 32: No strong peak found.
# Actuator 33: No strong peak found.
# Actuator 34: No strong peak found.
# Actuator 35: No strong peak found.
# Computing interaction matrix...
#
# Computing laplacian...

# %%
nmodes = 7

fig, ax = plt.subplots(figsize=(18, 5), ncols=3, nrows=1)

ax[0].set_title('PSD of modes')
ax[0].set_xlabel('Frequency (Hz)')
ax[0].set_ylabel('PSD of modes')
ax[0].plot(freq, psdmod[:, 0], linewidth=1)

for i in range(nmodes):
    color_val = float(i) * 200. / 36. + 50.
    ax[0].plot(freq, psdmod[:, i], linewidth=0.5)

ax[0].set_xlim(0.1, 10)
ax[0].set_ylim(0, 1)


ax[1].set_title('PSD of x-centroids')
ax[1].set_xlabel('Frequency (Hz)')
ax[1].set_ylabel('PSD')
# ax[1].plot(freq, psdmes[16, :], linewidth=1)

for i in range(4):
    color_val = i / 4
    ax[1].plot(freq, psdmes[:, i+4])
    
ax[1].set_xlim(0.1, 10)
# ax[1].set_ylim(-0.4, 0.4)

ax[2].set_title('PSD of y-centroids')
ax[2].set_xlabel('Frequency (Hz)')
ax[2].set_ylabel('PSD')

for i in range(4):
    color_val = i / 4
    ax[2].plot(freq, psdmes[:, i])
    
ax[2].set_xlim(0.1, 10)
# ax[2].set_ylim(-0.4, 0.4)

plt.show()

# %%
# The cmat will be generated by pyRTC.
# Run loop.saveIM() to save the cmat.
np.save("calib/imat/imat.cacofoni.20250930.a.npy", imat)

z2a = fits.getdata(z2a_file)
imat_zonal = imat @ z2a.T # this is what you would put into the imaka RTC
np.save("calib/imat/imat.cacofoni.zonal.20250930.a.npy", imat_zonal)

# %%
fits.writeto("calib/imat/imat.cacofoni.20250930.a.fits", imat, overwrite=True)
fits.writeto("calib/imat/imat.cacofoni.zonal.20250930.a.fits", imat_zonal, overwrite=True)

# %%
fns_aocb
# Out:
# ['/Users/ellenlee/Documents/pyRTC-IRTF/IRTF/data/20250930/aocb0000.fits',
#  '/Users/ellenlee/Documents/pyRTC-IRTF/IRTF/data/20250930/aocb0001.fits',
#  '/Users/ellenlee/Documents/pyRTC-IRTF/IRTF/data/20250930/aocb0002.fits']

# %%
imat_zonal.shape
# Out:
# (8, 36)
